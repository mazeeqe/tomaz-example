# %%
from pathlib import Path

parent_dir = Path("/home/mazeeqe/Documents")

# This is the child folder selected on the command line
#dataset_name = my_opts.dataset

child_path = parent_dir / dataset_name

if not child_path.is_dir():
    raise RuntimeError(f"Dataset folder not found: {child_path}")

# Recursively gather .slcio files
slcio_files = [str(p) for p in child_path.rglob("*.slcio") if p.is_file()]

print(f"Dataset {dataset_name} has {len(slcio_files)} input files")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       3 parent_dir = Path("/home/mazeeqe/Documents")
#       5 # This is the child folder selected on the command line
#       6 #dataset_name = my_opts.dataset
# ----> 8 child_path = parent_dir / dataset_name
#      10 if not child_path.is_dir():
#      11     raise RuntimeError(f"Dataset folder not found: {child_path}")
#
# NameError: name 'dataset_name' is not defined

# %%
import os
from pathlib import Path

def list_child_folders(parent_dir: str | Path) -> list[str]:
    p = Path(parent_dir)
    return sorted([d.name for d in p.iterdir() if d.is_dir()])

parent = "/home/mazeeqe/Documents"

child_folders = list_child_folders(parent)
if not child_folders:
    raise RuntimeError("No child folders found")

test = []
print("Child folders:")
for i, c in enumerate(child_folders):
    print(f"{i}: {c}")
    test.append(c)

test
# Out:
# Child folders:
# 0: .ipynb_checkpoints
# 1: Backup
# 2: BaianaSystem
# 3: Blender
# 4: Code
# 5: Curriculo
# 6: Dota2
# 7: Extra
# 8: Filmes
# 9: GODOT
# 10: Googletakeout
# 11: Livros
# 12: Médico
# 13: Pesquisa
# 14: ST
# 15: YT
# 16: bl2
# 17: comune
# 18: curseforge
# 19: ibmdatascience
# 20: mestrado
# 21: repo
# ['.ipynb_checkpoints',
#  'Backup',
#  'BaianaSystem',
#  'Blender',
#  'Code',
#  'Curriculo',
#  'Dota2',
#  'Extra',
#  'Filmes',
#  'GODOT',
#  'Googletakeout',
#  'Livros',
#  'Médico',
#  'Pesquisa',
#  'ST',
#  'YT',
#  'bl2',
#  'comune',
#  'curseforge',
#  'ibmdatascience',
#  'mestrado',
#  'repo']

# %%
for i in test:
    print(f"--{i}")
# Out:
# --.ipynb_checkpoints
# --Backup
# --BaianaSystem
# --Blender
# --Code
# --Curriculo
# --Dota2
# --Extra
# --Filmes
# --GODOT
# --Googletakeout
# --Livros
# --Médico
# --Pesquisa
# --ST
# --YT
# --bl2
# --comune
# --curseforge
# --ibmdatascience
# --mestrado
# --repo
